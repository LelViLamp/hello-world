# %%
# https://www.youtube.com/watch?v=C2FPN8RCDWw&list=PLxgDUj5eygKnSd4MYHIuAC7E3VEPm_WLO&index=15
# HISTOGRAM
import numpy as np
import matplotlib.pyplot as plt

# %%
# generate random numbers
X = np.random.randn(10_000)

# %%
# plot histogram
plt.hist(X)
plt.show()

# %%
plt.hist(X, bins=50)
plt.show()

# %%
X = np.random.random(10_000)
plt.hist(X, bins = 50)
plt.show()
