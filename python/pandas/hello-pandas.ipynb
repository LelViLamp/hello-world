# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Stadt" :               ["Berlin",  "Hamburg",  "München",  "Köln"],
    "Bundesland" :          ["Berlin",  "Hamburg",  "Bayern",   "NRW"],
    "Einwohner*innenzahl" : [3_644_826, 1_841_179,  1_471_508,  1_085_664],
})

# %%
df
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 0   Berlin     Berlin              3644826
# 1  Hamburg    Hamburg              1841179
# 2  München     Bayern              1471508
# 3     Köln        NRW              1085664

# %%
print(
    len(df),
    df.dtypes,
    df.columns,
    sep="\n"
)
# Out:
# 4
# Stadt                  object
# Bundesland             object
# Einwohner*innenzahl     int64
# dtype: object
# Index(['Stadt', 'Bundesland', 'Einwohner*innenzahl'], dtype='object')

# %%
df["Stadt"]
# Out:
# 0     Berlin
# 1    Hamburg
# 2    München
# 3       Köln
# Name: Stadt, dtype: object

# %%
type(df["Stadt"])
# Out:
# pandas.core.series.Series

# %%
df.Stadt
# Out:
# 0     Berlin
# 1    Hamburg
# 2    München
# 3       Köln
# Name: Stadt, dtype: object

# %%
df[["Stadt", "Einwohner*innenzahl"]]
# Out:
#      Stadt  Einwohner*innenzahl
# 0   Berlin              3644826
# 1  Hamburg              1841179
# 2  München              1471508
# 3     Köln              1085664

# %%
type(df[["Stadt", "Einwohner*innenzahl"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[1]
# Out:
# Stadt                  Hamburg
# Bundesland             Hamburg
# Einwohner*innenzahl    1841179
# Name: 1, dtype: object

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %%
df.loc[[1, 3]]
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 1  Hamburg    Hamburg              1841179
# 3     Köln        NRW              1085664

# %%
df.loc[1:3]
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 1  Hamburg    Hamburg              1841179
# 2  München     Bayern              1471508
# 3     Köln        NRW              1085664

# %%
df.loc[3, "Stadt"]
# Out:
# 'Köln'

# %%
df.loc[[1,3], "Stadt"]
# Out:
# 1    Hamburg
# 3       Köln
# Name: Stadt, dtype: object

# %%
df.loc[3, :]
# Out:
# Stadt                     Köln
# Bundesland                 NRW
# Einwohner*innenzahl    1085664
# Name: 3, dtype: object

# %%
df2 = pd.DataFrame({
    "Stadt" :               ["Berlin",  "Hamburg",  "München",  "Köln"],
    "Bundesland" :          ["Berlin",  "Hamburg",  "Bayern",   "NRW"],
    "Einwohner*innenzahl" : [3_644_826, 1_841_179,  1_471_508,  1_085_664],
}, index=["i1", "i2", "i3", "i4"])

# %%
df2
# Out:
#       Stadt Bundesland  Einwohner*innenzahl
# i1   Berlin     Berlin              3644826
# i2  Hamburg    Hamburg              1841179
# i3  München     Bayern              1471508
# i4     Köln        NRW              1085664

# %%
df2["i2":"i4"]
# df2["i2":]
# Out:
#       Stadt Bundesland  Einwohner*innenzahl
# i2  Hamburg    Hamburg              1841179
# i3  München     Bayern              1471508
# i4     Köln        NRW              1085664

# %%
df2 = df2.set_index("Stadt")

# %% [markdown]
# Note: you have to **assign** after using the `set_index` function!
#
# Result  | Code
# --------|-------------------------------
# Wrong   | `df2.set_index("Stadt")`
# Correct | `df2 = df2.set_index("Stadt")`

# %%
df2
# Out:
#         Bundesland  Einwohner*innenzahl
# Stadt
# Berlin      Berlin              3644826
# Hamburg    Hamburg              1841179
# München     Bayern              1471508
# Köln           NRW              1085664

# %%
df2["Hamburg":"Köln"]
# Out:
#         Bundesland  Einwohner*innenzahl
# Stadt
# Hamburg    Hamburg              1841179
# München     Bayern              1471508
# Köln           NRW              1085664

# %%
df.drop(0)
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 1  Hamburg    Hamburg              1841179
# 2  München     Bayern              1471508
# 3     Köln        NRW              1085664

# %%
df
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 0   Berlin     Berlin              3644826
# 1  Hamburg    Hamburg              1841179
# 2  München     Bayern              1471508
# 3     Köln        NRW              1085664

# %%
df.drop([0, 2])
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 1  Hamburg    Hamburg              1841179
# 3     Köln        NRW              1085664

# %%
df.drop("Bundesland", axis=1)
# Out:
#      Stadt  Einwohner*innenzahl
# 0   Berlin              3644826
# 1  Hamburg              1841179
# 2  München              1471508
# 3     Köln              1085664

# %%
df2 = pd.DataFrame({
    "Stadt" :               ["Frankfurt",   "Stuttgart",    "Düsseldorf",   "Dortmund"],
    "Bundesland" :          ["Hessen",      "BW",           "NRW",          "NRW"],
    "Einwohner*innenzahl" : [732_688,       623_738,        612_178,        586_181]
})

# %%
df.append(df2)
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              3644826
# 1     Hamburg    Hamburg              1841179
# 2     München     Bayern              1471508
# 3        Köln        NRW              1085664
# 0   Frankfurt     Hessen               732688
# 1   Stuttgart         BW               623738
# 2  Düsseldorf        NRW               612178
# 3    Dortmund        NRW               586181

# %%
df.append(df2, ignore_index=True)
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              3644826
# 1     Hamburg    Hamburg              1841179
# 2     München     Bayern              1471508
# 3        Köln        NRW              1085664
# 4   Frankfurt     Hessen               732688
# 5   Stuttgart         BW               623738
# 6  Düsseldorf        NRW               612178
# 7    Dortmund        NRW               586181

# %%
pd.concat([df, df2], ignore_index=True)
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              3644826
# 1     Hamburg    Hamburg              1841179
# 2     München     Bayern              1471508
# 3        Köln        NRW              1085664
# 4   Frankfurt     Hessen               732688
# 5   Stuttgart         BW               623738
# 6  Düsseldorf        NRW               612178
# 7    Dortmund        NRW               586181

# %%
pd.concat([df, df2], axis=1)
# Out:
#      Stadt Bundesland  Einwohner*innenzahl       Stadt Bundesland  \
# 0   Berlin     Berlin              3644826   Frankfurt     Hessen
# 1  Hamburg    Hamburg              1841179   Stuttgart         BW
# 2  München     Bayern              1471508  Düsseldorf        NRW
# 3     Köln        NRW              1085664    Dortmund        NRW
#
#    Einwohner*innenzahl
# 0               732688
# 1               623738
# 2               612178
# 3               586181

# %%
df3 = df.append(df2, ignore_index=True)
df3
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              3644826
# 1     Hamburg    Hamburg              1841179
# 2     München     Bayern              1471508
# 3        Köln        NRW              1085664
# 4   Frankfurt     Hessen               732688
# 5   Stuttgart         BW               623738
# 6  Düsseldorf        NRW               612178
# 7    Dortmund        NRW               586181

# %%
df3["Einwohner*innenzahl"] > 1_500_000
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Einwohner*innenzahl, dtype: bool

# %%
df3[df3["Einwohner*innenzahl"] > 1_500_000]
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 0   Berlin     Berlin              3644826
# 1  Hamburg    Hamburg              1841179

# %%
df[(df["Einwohner*innenzahl"] > 1_000_000) & (df.Bundesland != "NRW")]
# Out:
#      Stadt Bundesland  Einwohner*innenzahl
# 0   Berlin     Berlin              3644826
# 1  Hamburg    Hamburg              1841179
# 2  München     Bayern              1471508

# %%
df4 = df3.copy()
df4
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              3644826
# 1     Hamburg    Hamburg              1841179
# 2     München     Bayern              1471508
# 3        Köln        NRW              1085664
# 4   Frankfurt     Hessen               732688
# 5   Stuttgart         BW               623738
# 6  Düsseldorf        NRW               612178
# 7    Dortmund        NRW               586181

# %%
df4["Einwohner*innenzahl"] *= 2
df4
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin     Berlin              7289652
# 1     Hamburg    Hamburg              3682358
# 2     München     Bayern              2943016
# 3        Köln        NRW              2171328
# 4   Frankfurt     Hessen              1465376
# 5   Stuttgart         BW              1247476
# 6  Düsseldorf        NRW              1224356
# 7    Dortmund        NRW              1172362

# %%
df4.Bundesland = ["BE", "HH", "BY", "NW", "HE", "BW", "NW", "NW"]
df4
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin         BE              7289652
# 1     Hamburg         HH              3682358
# 2     München         BY              2943016
# 3        Köln         NW              2171328
# 4   Frankfurt         HE              1465376
# 5   Stuttgart         BW              1247476
# 6  Düsseldorf         NW              1224356
# 7    Dortmund         NW              1172362

# %%
df4.loc[df4.Bundesland == "NW", "Bundesland"] = "NRW"
df4
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0      Berlin         BE              7289652
# 1     Hamburg         HH              3682358
# 2     München         BY              2943016
# 3        Köln        NRW              2171328
# 4   Frankfurt         HE              1465376
# 5   Stuttgart         BW              1247476
# 6  Düsseldorf        NRW              1224356
# 7    Dortmund        NRW              1172362

# %%
df4.loc[0] = pd.Series({
    "Stadt" :               "Bonn",
    "Bundesland" :          "NRW",
    "Einwohner*innenzahl" : 318_809,
})
df4
# Out:
#         Stadt Bundesland  Einwohner*innenzahl
# 0        Bonn        NRW               318809
# 1     Hamburg         HH              3682358
# 2     München         BY              2943016
# 3        Köln        NRW              2171328
# 4   Frankfurt         HE              1465376
# 5   Stuttgart         BW              1247476
# 6  Düsseldorf        NRW              1224356
# 7    Dortmund        NRW              1172362

# %%
df3.plot(x="Stadt", y="Einwohner*innenzahl", kind="barh")
# Out:
# <AxesSubplot:ylabel='Stadt'>

# %%
df3.set_index("Stadt").plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Stadt'>

# %%
df3.set_index("Stadt").plot(y="Einwohner*innenzahl", kind="pie", legend=False)
# Out:
# <AxesSubplot:ylabel='Einwohner*innenzahl'>
